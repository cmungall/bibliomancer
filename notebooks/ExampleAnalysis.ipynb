# %%
import pandas as pd
df = pd.read_csv("../tests/output/cjm.minimal.csv")
df
# Out:
#                 type                                              title  \
# 0            Dataset                                                NaN
# 1    ConferencePaper  Planteome: Ontologies and Integrated Resources...
# 2           Software                                            OntoGPT
# 3           Preprint      Logic programming for the biomedical sciences
# 4             Report  Phenotype Ontologies Traversing All The Organi...
# ..               ...                                                ...
# 253   JournalArticle  KG-Hub-building and exchanging biological know...
# 254   JournalArticle  A roadmap for the functional annotation of pro...
# 255  ConferencePaper  Sample tracking and synthesis needs for explor...
# 256  ConferencePaper  Classifying Animal Breeds with the Vertebrate ...
# 257   JournalArticle  129. Standardization of cancer terminology in ...
#
#                                                authors         journal  \
# ...

# %%
df[df["title"].isna()]
# Out:
#        type title authors journal  doi  pmid pmcid  year volume issue pages  \
# 0   Dataset   NaN    ['']     NaN  NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 42  Dataset   NaN    ['']     NaN  NaN   NaN   NaN   NaN    NaN   NaN   NaN
#
#     num_authors  position  rank  significance role local_id
# 0             1       NaN   NaN           NaN  NaN      NaN
# 42            1       NaN   NaN           NaN  NaN      NaN

# %%
df["type"].value_counts()
# Out:
# type
# JournalArticle     165
# Preprint            36
# ConferencePaper     31
# Software            15
# Report               4
# Dataset              2
# BookChapter          2
# Dissertation         1
# News                 1
# Video or Film        1
# Name: count, dtype: int64

# %%
df[["type", "role"]].value_counts()
# Out:
# type             role
# JournalArticle   middle    114
#                  senior     19
#                  last       17
# Preprint         middle     16
# ConferencePaper  middle     16
#                  last        8
# JournalArticle   first       8
# Preprint         last        7
#                  first       6
# JournalArticle   lead        6
# Preprint         senior      5
# ConferencePaper  first       4
# Report           middle      2
# ConferencePaper  sole        2
# BookChapter      middle      2
# Report           first       1
#                  sole        1
# Preprint         sole        1
# JournalArticle   sole        1
# Preprint         lead        1
# News             senior      1
# Dissertation     sole        1
# ConferencePaper  lead        1
# Software         first       1
# Name: count, dtype: int64

# %%
df[["journal", "role"]].value_counts()
# Out:
# journal                         role
# Nucleic Acids Res.              middle    10
# Genome Biol.                    middle     8
# J. Biomed. Semantics            middle     7
# BMC Bioinformatics              middle     7
# J. Biomed. Semantics            last       6
#                                           ..
# Front Bioinform                 middle     1
# Ecol. Inform.                   last       1
# Drug Discov. Today Dis. Models  middle     1
# Dis. Model. Mech.               middle     1
# mSystems                        middle     1
# Name: count, Length: 94, dtype: int64

# %%
ja = df[df["type"] == "JournalArticle"]
main_journal = ja[ja["role"] != "middle"]
mid_journal = ja[ja["role"] == "middle"]

# %%
main_journal[["journal", "role"]].value_counts()
# Out:
# journal                role
# J. Biomed. Semantics   last      6
# Nucleic Acids Res.     senior    6
# Genome Biol.           first     3
# BMC Bioinformatics     last      2
# J. Biomed. Semantics   senior    2
# Database               last      2
# J. Biomed. Inform.     first     2
# Nat. Genet.            last      1
# J. Biomed. Semantics   lead      1
# Med                    senior    1
# Nucleic Acids Res.     lead      1
#                        first     1
# PLoS Biol.             senior    1
# PLoS Comput. Biol.     lead      1
# PLoS One               senior    1
# Patterns (N Y)         last      1
# Trends Ecol. Evol.     senior    1
# J. Biomed. Inform.     last      1
# Hum. Mutat.            lead      1
#                        senior    1
# Bioinformatics         first     1
# Hum. Mutat.            first     1
# Genome Res.            lead      1
# Genome Biol.           senior    1
# Genetics               senior    1
# Ecol. Inform.          last      1
# ...

# %%
main_journal[main_journal["journal"].isna()]
# Out:
# Empty DataFrame
# Columns: [type, title, authors, journal, doi, pmid, pmcid, year, volume, issue, pages, num_authors, position, rank, significance, role, local_id]
# Index: []

# %%
main_journal
# Out:
#                type                                              title  \
# 27   JournalArticle  ECO, the Evidence & Conclusion Ontology: commu...
# 28   JournalArticle  Uberon: towards a comprehensive multi-species ...
# 35   JournalArticle  The generic genome browser: a building block f...
# 38   JournalArticle  Knowledge Beacons: Web services for data harve...
# 53   JournalArticle  TermGenie - a web-application for pattern-base...
# 54   JournalArticle  The Monarch Initiative: an integrative data an...
# 55   JournalArticle  NSAID use and clinical outcomes in COVID-19 pa...
# 56   JournalArticle  Ontology Development Kit: a toolkit for buildi...
# 66   JournalArticle  The Environmental Conditions, Treatments, and ...
# 70   JournalArticle  Expansion of the Human Phenotype Ontology (HPO...
# 72   JournalArticle  Gene Ontology Causal Activity Modeling (GO-CAM...
# 75   JournalArticle  Biolink Model: A universal schema for knowledg...
# ...

# %%
mid_journal
# Out:
#                type                                              title  \
# 16   JournalArticle  Novel sequence feature variant type analysis o...
# 17   JournalArticle                       What is an anatomy ontology?
# 25   JournalArticle  Assessing the impact of comparative genomic se...
# 31   JournalArticle  The Gene Ontology (GO) database and informatic...
# 37   JournalArticle  Reactome and the Gene Ontology: digital conver...
# ..              ...                                                ...
# 238  JournalArticle  ECO: the Evidence and Conclusion Ontology, an ...
# 241  JournalArticle  The GA4GH Phenopacket schema defines a computa...
# 244  JournalArticle       GA4GH Phenopackets: A Practical Introduction
# 252  JournalArticle  Perspectives for self-driving labs in syntheti...
# 254  JournalArticle  A roadmap for the functional annotation of pro...
#
#                                                authors  \
# 16   ['Karp DR', 'Marthandan N', 'Marsh SG', 'Ahn C...
# ...
